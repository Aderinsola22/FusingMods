# %%
import random
### regular version
def fuse(probability,my_list):
    if random.random() < probability:
        print("fuse_success")
        print(random.choice(my_list))
        print("\n")
    else:
        print("fuse_failed\n")
        
color_string=input("What color are you trying to fuse: ")
grade_string=input("What grade are you trying to fuse: ")
grade_int=int(grade_string)
if(color_string == "Blue"):
    if(grade_int ==1):
        prob = 0.8
    elif(grade_int ==2):
        prob = 0.7
    elif(grade_int ==3):
        prob = 0.60 
    elif(grade_int >=4):    
        prob = 0.50
elif(color_string == "Purple"):
    if(grade_int ==2):
        prob = 0.60
    elif(grade_int ==3):
        prob= 0.55
    elif(grade_int >=4): 
        prob = 0.30
print(prob);    
fuse_list=[];
for i in range(0,3):
    acc_string =input("Enter the Attachment you want to fuse: ")
    fuse_list.append(acc_string);
print(fuse_list)
protection=input("Do you want to add protective materials Y/N?: ")
print("\n")
if(protection=="Y"):
    if(grade_int == 1):
        prob =1
        print(prob)
    else:
        prob=prob+0.15;
        print(prob)
        for i in range(10):
            fuse(prob,fuse_list)
else:
    print(prob)
    for i in range(10):
        fuse(prob,fuse_list)

# %%
### auto version
import random

fuse_success=0;
fuse_failed=0;
def fuse(probability,my_list):
    if random.random() < probability:
        print("fuse_success")
        global fuse_success
        fuse_success=fuse_success+1
        print(random.choice(my_list))
        print("\n")
    else:
        print("fuse_failed\n")
        global fuse_failed
        fuse_failed=fuse_failed+1
        
acc_list=['Light Stock','Heavy Stock','Knob','Cotton Layer','Light Sight','Heavy Sight','Hanging Tassel','Chain Layer','Light Muzzle','Heavy Muzzle','Sculpture','Steel Layer']
protect_mode=['Y','N']
color_string=['Blue','Purple']
grade_string=['5','6','7','8','9']
for i in range(100):
    fuse_list=[];
    color_input=random.choice(color_string)
    grade_input=random.choice(grade_string)
    grade_int=int(grade_input)
    print("\n")
    print("Color: ",color_input)
    print("Grade: ",grade_int)
    if(color_input == "Blue"):
      #  if(grade_int ==1):
      #      prob = 0.8
        if(grade_int ==2):
            prob = 0.7
        elif(grade_int ==3):
            prob = 0.60 
        elif(grade_int >=4):    
            prob = 0.50
    elif(color_input == "Purple"):
        if(grade_int ==2):
            prob = 0.60
        elif(grade_int ==3):
            prob= 0.55
        elif(grade_int >=4): 
            prob = 0.30
    print("chance before cores:",prob); 
    for i in range(3):
        fuse_list.append(random.choice(acc_list))
    print(fuse_list)    
    protection=random.choice(protect_mode)
    print("Protection: ",protection)
    if(protection=="Y"):
      #  if(grade_int == 1 and color_input=="Blue"):
       #     prob = 1
        #    print("chance after cores:",prob)
        #    fuse(prob,fuse_list)
        #else:
            prob=prob+0.15;
            print("chance after cores:",prob)
            fuse(prob,fuse_list)
    else:
        print("chance after cores:",prob)
        fuse(prob,fuse_list)
print("fuse success:",fuse_success)
print("fuse failed: ",fuse_failed)
# Out:
# Color:  Purple
# Grade:  6
# chance before cores: 0.3
# ['Hanging Tassel', 'Knob', 'Cotton Layer']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  7
# chance before cores: 0.5
# ['Chain Layer', 'Light Sight', 'Steel Layer']
# Protection:  N
# chance after cores: 0.5
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  5
# chance before cores: 0.3
# ['Light Stock', 'Hanging Tassel', 'Light Stock']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Hanging Tassel
#
#
#
#
# Color:  Purple
# Grade:  7
# chance before cores: 0.3
# ['Sculpture', 'Cotton Layer', 'Heavy Stock']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  6
# chance before cores: 0.3
# ['Light Stock', 'Heavy Stock', 'Heavy Muzzle']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Heavy Muzzle
#
#
#
#
# Color:  Blue
# Grade:  7
# chance before cores: 0.5
# ['Light Muzzle', 'Light Muzzle', 'Heavy Muzzle']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Heavy Muzzle
#
#
#
#
# Color:  Blue
# Grade:  5
# chance before cores: 0.5
# ['Light Muzzle', 'Steel Layer', 'Light Muzzle']
# Protection:  N
# chance after cores: 0.5
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  8
# chance before cores: 0.5
# ['Sculpture', 'Light Muzzle', 'Steel Layer']
# Protection:  N
# chance after cores: 0.5
# fuse_success
# Sculpture
#
#
#
#
# Color:  Blue
# Grade:  5
# chance before cores: 0.5
# ['Heavy Stock', 'Chain Layer', 'Heavy Muzzle']
# Protection:  N
# chance after cores: 0.5
# fuse_success
# Heavy Stock
#
#
#
#
# Color:  Blue
# Grade:  7
# chance before cores: 0.5
# ['Chain Layer', 'Heavy Muzzle', 'Hanging Tassel']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Heavy Muzzle
#
#
#
#
# Color:  Blue
# Grade:  8
# chance before cores: 0.5
# ['Light Sight', 'Cotton Layer', 'Chain Layer']
# Protection:  N
# chance after cores: 0.5
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  9
# chance before cores: 0.5
# ['Heavy Stock', 'Hanging Tassel', 'Light Stock']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Light Stock
#
#
#
#
# Color:  Blue
# Grade:  6
# chance before cores: 0.5
# ['Chain Layer', 'Heavy Stock', 'Heavy Sight']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Chain Layer
#
#
#
#
# Color:  Purple
# Grade:  7
# chance before cores: 0.3
# ['Steel Layer', 'Light Sight', 'Chain Layer']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Steel Layer
#
#
#
#
# Color:  Blue
# Grade:  8
# chance before cores: 0.5
# ['Heavy Muzzle', 'Heavy Sight', 'Steel Layer']
# Protection:  N
# chance after cores: 0.5
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  5
# chance before cores: 0.5
# ['Light Stock', 'Hanging Tassel', 'Steel Layer']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Hanging Tassel
#
#
#
#
# Color:  Blue
# Grade:  6
# chance before cores: 0.5
# ['Heavy Sight', 'Heavy Stock', 'Light Muzzle']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Light Muzzle
#
#
#
#
# Color:  Blue
# Grade:  8
# chance before cores: 0.5
# ['Heavy Sight', 'Cotton Layer', 'Heavy Muzzle']
# Protection:  N
# chance after cores: 0.5
# fuse_success
# Heavy Sight
#
#
#
#
# Color:  Blue
# Grade:  8
# chance before cores: 0.5
# ['Heavy Sight', 'Light Sight', 'Light Stock']
# Protection:  N
# chance after cores: 0.5
# fuse_success
# Heavy Sight
#
#
#
#
# Color:  Purple
# Grade:  9
# chance before cores: 0.3
# ['Steel Layer', 'Light Stock', 'Heavy Sight']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Heavy Sight
#
#
#
#
# Color:  Blue
# Grade:  8
# chance before cores: 0.5
# ['Light Stock', 'Heavy Muzzle', 'Light Muzzle']
# Protection:  Y
# chance after cores: 0.65
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  8
# chance before cores: 0.3
# ['Sculpture', 'Light Stock', 'Chain Layer']
# Protection:  N
# chance after cores: 0.3
# fuse_success
# Chain Layer
#
#
#
#
# Color:  Blue
# Grade:  9
# chance before cores: 0.5
# ['Cotton Layer', 'Sculpture', 'Knob']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Cotton Layer
#
#
#
#
# Color:  Purple
# Grade:  9
# chance before cores: 0.3
# ['Steel Layer', 'Light Sight', 'Knob']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  7
# chance before cores: 0.3
# ['Light Muzzle', 'Sculpture', 'Light Stock']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Light Stock
#
#
#
#
# Color:  Blue
# Grade:  9
# chance before cores: 0.5
# ['Knob', 'Hanging Tassel', 'Sculpture']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Sculpture
#
#
#
#
# Color:  Purple
# Grade:  8
# chance before cores: 0.3
# ['Heavy Muzzle', 'Heavy Sight', 'Sculpture']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Heavy Sight
#
#
#
#
# Color:  Purple
# Grade:  5
# chance before cores: 0.3
# ['Light Muzzle', 'Knob', 'Hanging Tassel']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Hanging Tassel
#
#
#
#
# Color:  Purple
# Grade:  8
# chance before cores: 0.3
# ['Heavy Muzzle', 'Hanging Tassel', 'Knob']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  7
# chance before cores: 0.5
# ['Heavy Stock', 'Heavy Muzzle', 'Heavy Sight']
# Protection:  N
# chance after cores: 0.5
# fuse_success
# Heavy Muzzle
#
#
#
#
# Color:  Purple
# Grade:  6
# chance before cores: 0.3
# ['Light Sight', 'Knob', 'Heavy Stock']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  9
# chance before cores: 0.5
# ['Knob', 'Knob', 'Light Sight']
# Protection:  N
# chance after cores: 0.5
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  9
# chance before cores: 0.5
# ['Cotton Layer', 'Sculpture', 'Cotton Layer']
# Protection:  N
# chance after cores: 0.5
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  9
# chance before cores: 0.5
# ['Heavy Stock', 'Light Sight', 'Light Stock']
# Protection:  Y
# chance after cores: 0.65
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  9
# chance before cores: 0.5
# ['Cotton Layer', 'Heavy Muzzle', 'Steel Layer']
# Protection:  N
# chance after cores: 0.5
# fuse_success
# Cotton Layer
#
#
#
#
# Color:  Blue
# Grade:  8
# chance before cores: 0.5
# ['Knob', 'Steel Layer', 'Light Stock']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Steel Layer
#
#
#
#
# Color:  Blue
# Grade:  7
# chance before cores: 0.5
# ['Light Sight', 'Sculpture', 'Sculpture']
# Protection:  N
# chance after cores: 0.5
# fuse_success
# Light Sight
#
#
#
#
# Color:  Purple
# Grade:  7
# chance before cores: 0.3
# ['Steel Layer', 'Heavy Stock', 'Cotton Layer']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Cotton Layer
#
#
#
#
# Color:  Purple
# Grade:  8
# chance before cores: 0.3
# ['Knob', 'Knob', 'Sculpture']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  5
# chance before cores: 0.3
# ['Light Stock', 'Light Sight', 'Chain Layer']
# Protection:  N
# chance after cores: 0.3
# fuse_success
# Chain Layer
#
#
#
#
# Color:  Purple
# Grade:  8
# chance before cores: 0.3
# ['Steel Layer', 'Sculpture', 'Light Stock']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  6
# chance before cores: 0.5
# ['Light Muzzle', 'Hanging Tassel', 'Sculpture']
# Protection:  N
# chance after cores: 0.5
# fuse_success
# Hanging Tassel
#
#
#
#
# Color:  Blue
# Grade:  6
# chance before cores: 0.5
# ['Cotton Layer', 'Heavy Stock', 'Light Sight']
# Protection:  Y
# chance after cores: 0.65
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  9
# chance before cores: 0.3
# ['Light Muzzle', 'Hanging Tassel', 'Steel Layer']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Light Muzzle
#
#
#
#
# Color:  Purple
# Grade:  5
# chance before cores: 0.3
# ['Light Sight', 'Knob', 'Hanging Tassel']
# Protection:  N
# chance after cores: 0.3
# fuse_success
# Knob
#
#
#
#
# Color:  Blue
# Grade:  8
# chance before cores: 0.5
# ['Heavy Sight', 'Hanging Tassel', 'Light Muzzle']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Light Muzzle
#
#
#
#
# Color:  Blue
# Grade:  8
# chance before cores: 0.5
# ['Heavy Sight', 'Chain Layer', 'Light Muzzle']
# Protection:  N
# chance after cores: 0.5
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  8
# chance before cores: 0.3
# ['Cotton Layer', 'Light Sight', 'Light Muzzle']
# Protection:  N
# chance after cores: 0.3
# fuse_success
# Light Sight
#
#
#
#
# Color:  Purple
# Grade:  6
# chance before cores: 0.3
# ['Light Sight', 'Hanging Tassel', 'Hanging Tassel']
# Protection:  N
# chance after cores: 0.3
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  5
# chance before cores: 0.5
# ['Chain Layer', 'Light Stock', 'Heavy Muzzle']
# Protection:  Y
# chance after cores: 0.65
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  5
# chance before cores: 0.5
# ['Heavy Muzzle', 'Knob', 'Chain Layer']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Knob
#
#
#
#
# Color:  Purple
# Grade:  8
# chance before cores: 0.3
# ['Light Stock', 'Light Muzzle', 'Heavy Sight']
# Protection:  N
# chance after cores: 0.3
# fuse_success
# Light Stock
#
#
#
#
# Color:  Purple
# Grade:  8
# chance before cores: 0.3
# ['Light Stock', 'Sculpture', 'Steel Layer']
# Protection:  N
# chance after cores: 0.3
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  6
# chance before cores: 0.5
# ['Light Sight', 'Knob', 'Cotton Layer']
# Protection:  N
# chance after cores: 0.5
# fuse_success
# Knob
#
#
#
#
# Color:  Purple
# Grade:  7
# chance before cores: 0.3
# ['Heavy Stock', 'Light Sight', 'Cotton Layer']
# Protection:  N
# chance after cores: 0.3
# fuse_success
# Heavy Stock
#
#
#
#
# Color:  Purple
# Grade:  9
# chance before cores: 0.3
# ['Steel Layer', 'Hanging Tassel', 'Light Stock']
# Protection:  N
# chance after cores: 0.3
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  7
# chance before cores: 0.5
# ['Heavy Stock', 'Light Stock', 'Heavy Stock']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Heavy Stock
#
#
#
#
# Color:  Blue
# Grade:  9
# chance before cores: 0.5
# ['Light Stock', 'Light Muzzle', 'Knob']
# Protection:  Y
# chance after cores: 0.65
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  9
# chance before cores: 0.5
# ['Heavy Sight', 'Steel Layer', 'Knob']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Steel Layer
#
#
#
#
# Color:  Purple
# Grade:  6
# chance before cores: 0.3
# ['Heavy Muzzle', 'Knob', 'Knob']
# Protection:  N
# chance after cores: 0.3
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  6
# chance before cores: 0.3
# ['Cotton Layer', 'Light Muzzle', 'Light Sight']
# Protection:  N
# chance after cores: 0.3
# fuse_success
# Cotton Layer
#
#
#
#
# Color:  Blue
# Grade:  7
# chance before cores: 0.5
# ['Heavy Stock', 'Knob', 'Light Muzzle']
# Protection:  N
# chance after cores: 0.5
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  9
# chance before cores: 0.5
# ['Heavy Stock', 'Heavy Stock', 'Hanging Tassel']
# Protection:  Y
# chance after cores: 0.65
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  8
# chance before cores: 0.3
# ['Hanging Tassel', 'Light Sight', 'Chain Layer']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  6
# chance before cores: 0.5
# ['Chain Layer', 'Steel Layer', 'Heavy Muzzle']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Steel Layer
#
#
#
#
# Color:  Blue
# Grade:  7
# chance before cores: 0.5
# ['Heavy Sight', 'Chain Layer', 'Hanging Tassel']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Chain Layer
#
#
#
#
# Color:  Blue
# Grade:  9
# chance before cores: 0.5
# ['Heavy Muzzle', 'Steel Layer', 'Chain Layer']
# Protection:  N
# chance after cores: 0.5
# fuse_success
# Steel Layer
#
#
#
#
# Color:  Purple
# Grade:  9
# chance before cores: 0.3
# ['Light Stock', 'Sculpture', 'Heavy Sight']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  7
# chance before cores: 0.3
# ['Chain Layer', 'Light Stock', 'Knob']
# Protection:  N
# chance after cores: 0.3
# fuse_success
# Knob
#
#
#
#
# Color:  Blue
# Grade:  9
# chance before cores: 0.5
# ['Cotton Layer', 'Heavy Sight', 'Hanging Tassel']
# Protection:  N
# chance after cores: 0.5
# fuse_success
# Heavy Sight
#
#
#
#
# Color:  Purple
# Grade:  5
# chance before cores: 0.3
# ['Heavy Stock', 'Light Muzzle', 'Light Muzzle']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  6
# chance before cores: 0.3
# ['Chain Layer', 'Knob', 'Light Stock']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Chain Layer
#
#
#
#
# Color:  Purple
# Grade:  5
# chance before cores: 0.3
# ['Chain Layer', 'Cotton Layer', 'Knob']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Cotton Layer
#
#
#
#
# Color:  Purple
# Grade:  6
# chance before cores: 0.3
# ['Steel Layer', 'Hanging Tassel', 'Light Muzzle']
# Protection:  N
# chance after cores: 0.3
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  9
# chance before cores: 0.5
# ['Heavy Stock', 'Hanging Tassel', 'Sculpture']
# Protection:  Y
# chance after cores: 0.65
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  6
# chance before cores: 0.3
# ['Sculpture', 'Cotton Layer', 'Steel Layer']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  8
# chance before cores: 0.5
# ['Cotton Layer', 'Light Stock', 'Chain Layer']
# Protection:  N
# chance after cores: 0.5
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  9
# chance before cores: 0.3
# ['Steel Layer', 'Heavy Stock', 'Hanging Tassel']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Heavy Stock
#
#
#
#
# Color:  Blue
# Grade:  5
# chance before cores: 0.5
# ['Cotton Layer', 'Knob', 'Heavy Stock']
# Protection:  N
# chance after cores: 0.5
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  8
# chance before cores: 0.3
# ['Heavy Stock', 'Light Muzzle', 'Light Sight']
# Protection:  N
# chance after cores: 0.3
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  8
# chance before cores: 0.3
# ['Light Stock', 'Knob', 'Light Muzzle']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Knob
#
#
#
#
# Color:  Purple
# Grade:  8
# chance before cores: 0.3
# ['Knob', 'Cotton Layer', 'Heavy Muzzle']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Cotton Layer
#
#
#
#
# Color:  Purple
# Grade:  6
# chance before cores: 0.3
# ['Light Muzzle', 'Light Sight', 'Light Sight']
# Protection:  N
# chance after cores: 0.3
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  6
# chance before cores: 0.3
# ['Light Stock', 'Sculpture', 'Cotton Layer']
# Protection:  N
# chance after cores: 0.3
# fuse_success
# Cotton Layer
#
#
#
#
# Color:  Purple
# Grade:  5
# chance before cores: 0.3
# ['Chain Layer', 'Sculpture', 'Heavy Muzzle']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_success
# Chain Layer
#
#
#
#
# Color:  Blue
# Grade:  6
# chance before cores: 0.5
# ['Heavy Stock', 'Sculpture', 'Steel Layer']
# Protection:  Y
# chance after cores: 0.65
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  9
# chance before cores: 0.5
# ['Chain Layer', 'Cotton Layer', 'Hanging Tassel']
# Protection:  Y
# chance after cores: 0.65
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  5
# chance before cores: 0.5
# ['Heavy Muzzle', 'Light Sight', 'Light Muzzle']
# Protection:  Y
# chance after cores: 0.65
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  8
# chance before cores: 0.5
# ['Light Stock', 'Heavy Stock', 'Light Muzzle']
# Protection:  N
# chance after cores: 0.5
# fuse_success
# Heavy Stock
#
#
#
#
# Color:  Purple
# Grade:  9
# chance before cores: 0.3
# ['Light Sight', 'Chain Layer', 'Heavy Stock']
# Protection:  Y
# chance after cores: 0.44999999999999996
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  8
# chance before cores: 0.5
# ['Light Stock', 'Cotton Layer', 'Light Muzzle']
# Protection:  Y
# chance after cores: 0.65
# fuse_success
# Cotton Layer
#
#
#
#
# Color:  Purple
# Grade:  6
# chance before cores: 0.3
# ['Light Muzzle', 'Light Sight', 'Heavy Sight']
# Protection:  N
# chance after cores: 0.3
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  6
# chance before cores: 0.3
# ['Light Sight', 'Knob', 'Sculpture']
# Protection:  N
# chance after cores: 0.3
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  8
# chance before cores: 0.5
# ['Chain Layer', 'Steel Layer', 'Heavy Muzzle']
# Protection:  N
# chance after cores: 0.5
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  8
# chance before cores: 0.3
# ['Light Stock', 'Sculpture', 'Steel Layer']
# Protection:  N
# chance after cores: 0.3
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  7
# chance before cores: 0.5
# ['Cotton Layer', 'Heavy Muzzle', 'Heavy Stock']
# Protection:  N
# chance after cores: 0.5
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  6
# chance before cores: 0.5
# ['Heavy Muzzle', 'Light Sight', 'Steel Layer']
# Protection:  N
# chance after cores: 0.5
# fuse_success
# Heavy Muzzle
#
#
#
#
# Color:  Purple
# Grade:  9
# chance before cores: 0.3
# ['Heavy Muzzle', 'Cotton Layer', 'Cotton Layer']
# Protection:  N
# chance after cores: 0.3
# fuse_failed
#
#
#
# Color:  Blue
# Grade:  6
# chance before cores: 0.5
# ['Steel Layer', 'Cotton Layer', 'Light Stock']
# Protection:  N
# chance after cores: 0.5
# fuse_failed
#
#
#
# Color:  Purple
# Grade:  8
# chance before cores: 0.3
# ['Light Sight', 'Heavy Muzzle', 'Knob']
# Protection:  N
# chance after cores: 0.3
# fuse_success
# Light Sight
#
#
# fuse success: 54
# fuse failed:  46
